# %%
import pandas as pd

# %%
income = pd.DataFrame.from_csv('2007_-_2011_Median_Income_by_Neighborhood.csv')

# %%
housing = pd.DataFrame.from_csv('2013_Housing_Stock_and_Residential_Properties_by_Neighborhood.csv')

# %%
result = pd.concat([income,housing], axis=2, join='inner')

# %%
result.drop(['Centerpoint X','Centerpoint Y','Neighborhood Center Point '], axis=1, inplace=True)

# %%
result.drop([result.columns[3]], axis=1, inplace=True)

# %%
result
# Out:
#                       Median Household Income Median Family Income  \
# Neighborhood
# East Cambridge                      $70671.00           $103757.00
# Area 2/MIT                          $50226.00            $31249.00
# Wellington-Harrington               $50593.00            $49184.00
# Area Four                           $59119.00            $59384.00
# Cambridgeport                       $68168.00            $95381.00
# Mid-Cambridge                       $70940.00           $103366.00
# Riverside                           $54371.00            $66535.00
# Agassiz                             $79428.00           $165410.00
# Neighborhood Nine                   $76975.00           $119302.00
# West Cambridge                     $108501.00           $150870.00
# North Cambridge                     $66255.00            $76967.00
# Cambridge Highlands                 $68970.00            $70832.00
# Strawberry Hill                     $64374.00           $100151.00
# ...
